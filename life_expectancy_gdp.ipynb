# %%
git init
# Out:
#   Cell In[2], line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /Users/Kyle_Borzoni/Downloads/Life-Expectancy-and-GDP-Starter/.git/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df_gdp = pd.read_csv('all_data.csv')

# %%
print(df_gdp.head())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
git add
# Out:
#   Cell In[12], line 1
#     git add
#         ^
# SyntaxError: invalid syntax

# %%
# !git add
# Out:
# Nothing specified, nothing added.
# hint: Maybe you wanted to say 'git add .'?
# hint: Disable this message with "git config advice.addEmptyPathspec false"

# %%
df_gdp.rename(columns={"Life expectancy at birth (years)": "LEABY"}, inplace=True)

# %%
print(df_gdp.head())
# Out:
#   Country  Year  LEABY           GDP
# 0   Chile  2000   77.3  7.786093e+10
# 1   Chile  2001   77.3  7.097992e+10
# 2   Chile  2002   77.8  6.973681e+10
# 3   Chile  2003   77.9  7.564346e+10
# 4   Chile  2004   78.0  9.921039e+10

# %%
# !git add
# Out:
# Nothing specified, nothing added.
# hint: Maybe you wanted to say 'git add .'?
# hint: Disable this message with "git config advice.addEmptyPathspec false"

# %%
# !git add life_expectancy_gdp
# Out:
# fatal: pathspec 'life_expectancy_gdp' did not match any files

# %%
# !git add life_expectancy_gdp.ipynb

# %%
# !git commit -m "Added csv file, and changed column name "Life expectancy by year" to the abbreviated "LEABY""
# Out:
# error: pathspec 'expectancy' did not match any file(s) known to git
# error: pathspec 'by' did not match any file(s) known to git
# error: pathspec 'year to the abbreviated LEABY' did not match any file(s) known to git

# %%
# !git commit -m "Added csv file, and changed long column name to abbreviation"
# Out:
# [master (root-commit) 170cf33] Added csv file, and changed long column name to abbreviation
#  Committer: Kyle A Borzoni <Kyle_Borzoni@KylesCrnStation.attlocal.net>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 208 insertions(+)
#  create mode 100644 life_expectancy_gdp.ipynb

# %%
ax = sns.barpot(x = "Country", y = "GDP", data = df_gdp)
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 ax = sns.barpot(x = "Country", y = "GDP", data = df_gdp)
#       2 plt.xticks(rotation = 90)
#       3 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'barpot'

# %%
ax = sns.bar(x = "Country", y = "GDP", data = df_gdp)
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 ax = sns.bar(x = "Country", y = "GDP", data = df_gdp)
#       2 plt.xticks(rotation = 90)
#       3 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'bar'

# %%
ax = sns.barplot(x = "Country", y = "GDP", data = df_gdp, hue='Country')
plt.xticks(rotation = 90)
plt.show()

# %%
ax = sns.barplot(x="Country", y="LEABY", data=df_gdp, hue='Country')
plt.xticks(rotation=90)
plt.show()

# %%
# !git add life_expectancy_gdp.ipynb

# %%
# !git commit -m "Added bar charts for GDP by country, and Life expectancy by country"
# Out:
# [master 13bea0f] Added bar charts for GDP by country, and Life expectancy by country
#  Committer: Kyle A Borzoni <Kyle_Borzoni@KylesCrnStation.attlocal.net>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 167 insertions(+), 2 deletions(-)

# %%
f, ax = plt.subplots(figsize=(10,15))
ax = sns.barplot(x="Country", y="GDP", hue="Year", data=df_gdp)
plt.xticks(rotation=90)
ylabel = "GDP in trillions of US Dollars"
plt.ylabel(ylabel)
plt.title("GDP Over Time")
plt.show()

# %%
# !git add life_expectancy_gdp.ipynb

# %%
# !git commit -m "Created bar chart of GDP per country over time"
# Out:
# [master e325304] Created bar chart of GDP per country over time
#  Committer: Kyle A Borzoni <Kyle_Borzoni@Kyles-Creation-Station.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 66 insertions(+), 6 deletions(-)

# %%
f, ax = plt.subplots(figsize=(10,15))
ax = sns.barplot(x="Country", y="LEABY", hue="Year", data=df_gdp)
plt.xticks(rotation=90)
ylabel = "Life expectancy at birth in years"
plt.ylabel(ylabel)
plt.title("Life expectacy over time")
plt.show()

# %%
# !git add life_expectancy_gdp.ipynb

# %%
# !git commit -m "Added bar chart for life expectancy over time"
# Out:
# [master f557cd5] Added bar chart for life expectancy over time
#  Committer: Kyle A Borzoni <Kyle_Borzoni@Kyles-Creation-Station.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 62 insertions(+), 9 deletions(-)

# %%
g = sns.FacetGrid(df_gdp, col="Year", hue="Country", col_wrap=4)
g = (g.map(plt.scatter, "GDP", "LEABY", edgecolor="w").add_legend())
plt.show()

# %%
# !git add life_expectancy_gdp.ipynb

# %%
# !git commit -m "Added scatter plots for each year displaying the life expectancy of each country compared against their GDP"
# Out:
# [master 4861283] Added scatter plots for each year displaying the life expectancy of each country compared against their GDP
#  Committer: Kyle A Borzoni <Kyle_Borzoni@Kyles-Creation-Station.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 87 insertions(+), 5 deletions(-)

# %%
g3 = sns.FacetGrid(df_gdp, col="Country", col_wrap=3)
g3 = (g3.map(plt.plot, "Year", "LEABY", color="m").add_legend())
plt.show()

# %%
# !git add life_expectancy_gdp.ipynb

# %%
# !git commit -m "Added line graphs for increasing life expectancy per year for each country"
# Out:
# [master 6715903] Added line graphs for increasing life expectancy per year for each country
#  Committer: Kyle A Borzoni <Kyle_Borzoni@Kyles-Creation-Station.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly. Run the
# following command and follow the instructions in your editor to edit
# your configuration file:
#
#     git config --global --edit
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 68 insertions(+), 10 deletions(-)

# %%
life_exp = []
for co in df_gdp["Country"].unique():
  mean = np.mean(df_gdp.loc[df_gdp["Country"] == co, "LEABY"].values[0])
  life_exp.append("The life expectany in " + str(co) + " is " + str(mean) + " years.")

# %%
print(life_exp)
# Out:
# ['The life expectany in Chile is 77.3 years.', 'The life expectany in China is 71.7 years.', 'The life expectany in Germany is 78.0 years.', 'The life expectany in Mexico is 74.8 years.', 'The life expectany in United States of America is 76.8 years.', 'The life expectany in Zimbabwe is 46.0 years.']
